# %%
import pandas as pd

# %%
data=pd.read_csv("student_mental_health.csv")
data
# Out:
#     student_id  age             gender  year_of_study major_category  \
# 0      STU1001   22             Female              3       Business
# 1      STU1002   19                  M              2       Business
# 2      STU1003   23  Prefer not to say              3           STEM
# 3      STU1004   23               Male              2     Humanities
# 4      STU1005   17             Female              5           Arts
# ..         ...  ...                ...            ...            ...
# 495    STU1496   23             Female              5            Law
# 496    STU1497   18             Female              3           STEM
# 497    STU1498   21             Female              3           STEM
# 498    STU1499   17               Male              4           STEM
# 499    STU1500   18               Male              5       Business
#
#      daily_sleep_hours  daily_screen_time_hours  \
# 0                  6.1                      4.1
# ...

# %%
data.columns
# Out:
# Index(['student_id', 'age', 'gender', 'year_of_study', 'major_category',
#        'daily_sleep_hours', 'daily_screen_time_hours',
#        'physical_activity_days_per_week', 'phq9_score', 'gad7_score',
#        'perceived_stress_scale', 'weekly_study_hours',
#        'class_attendance_percent', 'online_learning_satisfaction',
#        'has_part_time_job', 'financial_stress', 'semester_type', 'cgpa'],
#       dtype='str')

# %%
data.shape
# Out:
# (500, 18)

# %%
data.info
# Out:
# <bound method DataFrame.info of     student_id  age             gender  year_of_study major_category  \
# 0      STU1001   22             Female              3       Business
# 1      STU1002   19                  M              2       Business
# 2      STU1003   23  Prefer not to say              3           STEM
# 3      STU1004   23               Male              2     Humanities
# 4      STU1005   17             Female              5           Arts
# ..         ...  ...                ...            ...            ...
# 495    STU1496   23             Female              5            Law
# 496    STU1497   18             Female              3           STEM
# 497    STU1498   21             Female              3           STEM
# 498    STU1499   17               Male              4           STEM
# 499    STU1500   18               Male              5       Business
#
#      daily_sleep_hours  daily_screen_time_hours  \
# 0                  6.1                      4.1
# ...

# %%
from matplotlib import pyplot as plt

# %%
data.isnull().sum()
# Out:
# student_id                          0
# age                                 0
# gender                              0
# year_of_study                       0
# major_category                      0
# daily_sleep_hours                   0
# daily_screen_time_hours             0
# physical_activity_days_per_week     0
# phq9_score                         14
# gad7_score                         14
# perceived_stress_scale              0
# weekly_study_hours                  0
# class_attendance_percent            0
# online_learning_satisfaction       24
# has_part_time_job                   0
# financial_stress                    0
# semester_type                       0
# cgpa                               12
# dtype: int64

# %%
data.drop(columns=["student_id","year_of_study","daily_screen_time_hours","phq9_score","gad7_score","class_attendance_percent","weekly_study_hours","online_learning_satisfaction",
"semester_type","cgpa"],inplace=True)
data
# Out:
#      age             gender major_category  daily_sleep_hours  \
# 0     22             Female       Business                6.1
# 1     19                  M       Business                7.0
# 2     23  Prefer not to say           STEM                5.0
# 3     23               Male     Humanities                3.8
# 4     17             Female           Arts                5.8
# ..   ...                ...            ...                ...
# 495   23             Female            Law                5.9
# 496   18             Female           STEM                5.0
# 497   21             Female           STEM                5.9
# 498   17               Male           STEM                5.5
# 499   18               Male       Business                3.8
#
#      physical_activity_days_per_week  perceived_stress_scale  \
# 0                                  1                      26
# 1                                  3                      19
# ...

# %%
data["age"].value_counts().plot(kind="bar")
plt.show()

# %%
data["age"].value_counts().plot(kind="pie")
plt.show()

# %%
data["age"].value_counts().plot(kind="hist")
plt.show()

# %%
data["gender"].value_counts().plot(kind="bar")
plt.show()

# %%
data["gender"].value_counts().plot(kind="pie")
plt.show()

# %%
data["gender"].value_counts().plot(kind="hist")
plt.show()

# %%
data["major_category"].value_counts().plot(kind="bar")
plt.show()

# %%
data["major_category"].value_counts().plot(kind="pie")
plt.show()

# %%
data["major_category"].value_counts().plot(kind="hist")
plt.show()

# %%
data["daily_sleep_hours"].value_counts().plot(kind="bar")
plt.show()

# %%
data["daily_sleep_hours"].value_counts().plot(kind="pie")
plt.show()

# %%
data["daily_sleep_hours"].value_counts().plot(kind="hist")
plt.show()

# %%
data["physical_activity_days_per_week"].value_counts().plot(kind="bar")
plt.show()

# %%
data["physical_activity_days_per_week"].value_counts().plot(kind="pie")
plt.show()

# %%
data["physical_activity_days_per_week"].value_counts().plot(kind="hist")
plt.show()

# %%
data["perceived_stress_scale"].value_counts().plot(kind="bar")
plt.show()

# %%
data["perceived_stress_scale"].value_counts().plot(kind="pie")
plt.show()

# %%
data["perceived_stress_scale"].value_counts().plot(kind="hist")
plt.show()
